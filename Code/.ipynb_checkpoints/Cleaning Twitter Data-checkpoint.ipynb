# %% [markdown]
# # Cleaning

# %%
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import stop_words
from nltk.stem.porter import PorterStemmer

from bs4 import BeautifulSoup 

import datetime as dt

from warnings import catch_warnings
from warnings import filterwarnings
import warnings

warnings.simplefilter(action="ignore")

# %%
df_WI = pd.read_csv('../datasets/df_WI.csv')

# %%
df_WI
# Out:
#       Unnamed: 0                       Date  Favorites  Geolocation Hashtags  \
# 0              0  2019-07-19 23:47:00+00:00          0          NaN      NaN
# 1              1  2019-07-19 23:38:26+00:00          0          NaN      NaN
# 2              2  2019-07-19 23:38:08+00:00          0          NaN      NaN
# 3              3  2019-07-19 23:34:05+00:00          0          NaN      NaN
# 4              4  2019-07-19 23:34:01+00:00          0          NaN      NaN
# ...          ...                        ...        ...          ...      ...
# 1441        1441  2019-12-16 19:33:32+00:00          1          NaN      NaN
# 1442        1442  2019-12-16 19:19:56+00:00          0          NaN      NaN
# 1443        1443  2019-12-16 19:15:45+00:00          0          NaN      NaN
# 1444        1444  2019-12-16 18:55:27+00:00          0          NaN      NaN
# 1445        1445  2019-12-16 18:46:21+00:00          0          NaN      NaN
#
#      Mentions  Retweets                                               Text  \
# 0         NaN         0  Minato high diff Itachi wouldn't have the time...
# 1         NaN         0  At 6:45 PM EDT, Scotch Plains [Union Co, NJ] B...
# 2         NaN         0  At 6:45 PM EDT, Scotch Plains [Union Co, NJ] B...
# 3         NaN         0  At 6:45 PM EDT, Clark [Union Co, NJ] BROADCAST...
# 4         NaN         0  The properties should not be allowed to be sol...
# ...       ...       ...                                                ...
# 1441      NaN         1  There was always that goofy religious person b...
# 1442      NaN         2                      A flood would be *chefs kiss*
# 1443      NaN         1                         Wednesday is early signing
# 1444      NaN         2  people believe in the story of jonah’s arc and...
# 1445      NaN         4  Anytime I complete even the easiest household ...
#
#                 User  target      user_split  \
# 0          KidKinsey       0       KidKinsey
# 1         iembot_okx       1      iembot okx
# 2         iembot_okx       1      iembot okx
# 3         iembot_okx       1      iembot okx
# 4           a_diener       1        a diener
# ...              ...     ...             ...
# 1441      sleepyjoe2       0      sleepyjoe2
# 1442      Shimoji___       0      Shimoji
# 1443        duff8800       0        duff8800
# 1444   carsonnconner       0   carsonnconner
# 1445  CourtsideCorey       0  CourtsideCorey
#
#                                               user_text location
# 0     KidKinsey Minato high diff Itachi wouldn't hav...       WI
# 1     iembot okx At 6:45 PM EDT, Scotch Plains [Unio...       WI
# 2     iembot okx At 6:45 PM EDT, Scotch Plains [Unio...       WI
# 3     iembot okx At 6:45 PM EDT, Clark [Union Co, NJ...       WI
# 4     a diener The properties should not be allowed ...       WI
# ...                                                 ...      ...
# 1441  sleepyjoe2 There was always that goofy religio...       WI
# 1442           Shimoji    A flood would be *chefs kiss*       WI
# 1443                duff8800 Wednesday is early signing       WI
# 1444  carsonnconner people believe in the story of j...       WI
# 1445  CourtsideCorey Anytime I complete even the eas...       WI
#
# [1446 rows x 13 columns]

# %%
df_WI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1446 entries, 0 to 1445
# Data columns (total 13 columns):
# Unnamed: 0     1446 non-null int64
# Date           1446 non-null object
# Favorites      1446 non-null int64
# Geolocation    0 non-null float64
# Hashtags       280 non-null object
# Mentions       181 non-null object
# Retweets       1446 non-null int64
# Text           1442 non-null object
# User           1446 non-null object
# target         1446 non-null int64
# user_split     1446 non-null object
# user_text      1446 non-null object
# location       1446 non-null object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 147.0+ KB

# %%
df_TX = pd.read_csv('../datasets/df_TX.csv')
df_TX.head()
# Out:
#    Unnamed: 0        User                                               Text  \
# 0           0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1           1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2           2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3           3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4           4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                         Date  Favorites  Retweets Mentions Hashtags  \
# 0  2016-06-23 23:53:45+00:00          0         0      NaN     #RLX
# 1  2016-06-23 23:50:46+00:00          0         0      NaN     #RLX
# 2  2016-06-23 23:48:01+00:00          0         0      NaN     #RLX
# 3  2016-06-23 22:27:16+00:00          0         0      NaN     #RLX
# 4  2016-06-23 22:23:57+00:00          0         0      NaN     #RNK
#
#    Geolocation  user_split                                          user_text  \
# 0          NaN  iembot rlx  iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...
# 1          NaN  iembot rlx  iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...
# 2          NaN  iembot rlx  iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...
# 3          NaN  iembot rlx  iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...
# 4          NaN  iembot rnk  iembot rnk At 6:00 PM, Renick [Greenbrier Co, ...
#
#    target location
# 0       1       TX
# 1       1       TX
# 2       1       TX
# 3       1       TX
# 4       1       TX

# %%
df_concat = pd.concat([df_WI, df_TX], ignore_index = True)

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3446 entries, 0 to 3445
# Data columns (total 13 columns):
# Date           3446 non-null object
# Favorites      3446 non-null int64
# Geolocation    0 non-null float64
# Hashtags       1546 non-null object
# Mentions       253 non-null object
# Retweets       3446 non-null int64
# Text           3442 non-null object
# Unnamed: 0     3446 non-null int64
# User           3446 non-null object
# location       3446 non-null object
# target         3446 non-null int64
# user_split     3446 non-null object
# user_text      3446 non-null object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 350.1+ KB

# %%
# drop Unanamed: 0, geolocation, User, user_split, Text columns
df_concat.drop(columns = ['Unnamed: 0', 'Geolocation', 'User'], inplace = True)

# %%
df_concat
# Out:
#                            Date  Favorites  HashTags                 Mentions  \
# 0     2019-07-19 22:40:31+00:00          0  #Respect  @BBCWorld @BigCatRescue
# 1     2019-07-19 22:26:34+00:00          0       NaN                      NaN
# 2     2019-07-19 22:19:05+00:00          1       NaN                      NaN
# 3     2019-07-19 22:17:13+00:00          0       NaN                      NaN
# 4     2019-07-19 20:57:18+00:00          0       NaN                      NaN
# ...                         ...        ...       ...                      ...
# 2698  2016-09-02 09:56:07+00:00          0       NaN          @SarahFortnerWx
# 2699  2016-09-02 05:19:09+00:00         56       NaN                      NaN
# 2700  2016-09-02 04:47:49+00:00          0       NaN                      NaN
# 2701  2016-09-02 02:49:25+00:00          0       NaN                      NaN
# 2702  2016-09-02 02:46:37+00:00          0       NaN                      NaN
#
#       Retweets                                               Text location  \
# 0            1  Nice to have a positive story about big cats f...       WI
# 1            0  my dad just told me to flood my car so I can g...       WI
# 2            2             Happy B-day Reggie, from the office!!!       WI
# 3            0  Something about how crime will magically drop ...       WI
# 4            0  Lol mine too. I’ve been avoiding floods for th...       WI
# ...        ...                                                ...      ...
# 2698         0  Flash flood watch for Charlotte and eastward u...       TX
# 2699        18   Move to higher ground! Flash Flood Warning in...       TX
# 2700         0  Help arrives for Greenspoint flood victi http:...       TX
# 2701         3  W my fellow Capital Correspondents raising $fo...       TX
# 2702         0  Flood party @Charleston, South Carolina https:...       TX
#
#       target      user_split  \
# 0          0      Gabriettaa
# 1          1     chaaasiti04
# 2          1         JDenius
# 3          1   beganovic2021
# 4          1  RiskItAllRichy
# ...      ...             ...
# 2698       0     CharlotteCP
# 2699       0  NWSTallahassee
# 2700       0     BLifeAldine
# 2701       0    Futureteller
# 2702       0         ClayDix
#
#                                               user_text
# 0     Gabriettaa Nice to have a positive story about...
# 1     chaaasiti04 my dad just told me to flood my ca...
# 2        JDenius Happy B-day Reggie, from the office!!!
# 3     beganovic2021 Something about how crime will m...
# 4     RiskItAllRichy Lol mine too. I’ve been avoidin...
# ...                                                 ...
# 2698  CharlotteCP Flash flood watch for Charlotte an...
# 2699  NWSTallahassee  Move to higher ground! Flash F...
# 2700  BLifeAldine Help arrives for Greenspoint flood...
# 2701  Futureteller W my fellow Capital Correspondent...
# 2702  ClayDix Flood party @Charleston, South Carolin...
#
# [2703 rows x 10 columns]

# %%
# Change Date column to datetime
df_concat['Date'] = pd.to_datetime(df_concat['Date'])

# %%
df_concat['Date'].dtypes
# Out:
# datetime64[ns, UTC]

# %%
# Analyze Nulls
df_concat.isnull().sum().sort_values(ascending=False)
# Out:
# Mentions      2542
# HashTags      1324
# Text             1
# user_text        0
# user_split       0
# target           0
# location         0
# Retweets         0
# Favorites        0
# Date             0
# dtype: int64

# %%
df_concat['Mentions'].fillna('None', inplace = True)
df_concat['HashTags'].fillna('None', inplace = True)

# %%
df_concat.shape
# Out:
# (2703, 10)

# %%
df_concat['Text'].isnull().sum()
# Out:
# 1

# %%
df_concat.drop(index = df_concat[df_concat['Text'].isnull()].index, inplace = True)

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2702 entries, 0 to 2702
# Data columns (total 10 columns):
# Date          2702 non-null datetime64[ns, UTC]
# Favorites     2702 non-null int64
# HashTags      2702 non-null object
# Mentions      2702 non-null object
# Retweets      2702 non-null int64
# Text          2702 non-null object
# location      2702 non-null object
# target        2702 non-null int64
# user_split    2702 non-null object
# user_text     2702 non-null object
# dtypes: datetime64[ns, UTC](1), int64(3), object(6)
# memory usage: 232.2+ KB

# %%
df_concat.to_csv('../Data/df_TX_WI_clean.csv')

# %%
pd.read_csv('../Data/df_TX_WI_clean.csv')
# Out:
#       Unnamed: 0                       Date  Favorites  HashTags  \
# 0              0  2019-07-19 22:40:31+00:00          0  #Respect
# 1              1  2019-07-19 22:26:34+00:00          0      None
# 2              2  2019-07-19 22:19:05+00:00          1      None
# 3              3  2019-07-19 22:17:13+00:00          0      None
# 4              4  2019-07-19 20:57:18+00:00          0      None
# ...          ...                        ...        ...       ...
# 2697        2698  2016-09-02 09:56:07+00:00          0      None
# 2698        2699  2016-09-02 05:19:09+00:00         56      None
# 2699        2700  2016-09-02 04:47:49+00:00          0      None
# 2700        2701  2016-09-02 02:49:25+00:00          0      None
# 2701        2702  2016-09-02 02:46:37+00:00          0      None
#
#                      Mentions  Retweets  \
# 0     @BBCWorld @BigCatRescue         1
# 1                        None         0
# 2                        None         2
# 3                        None         0
# 4                        None         0
# ...                       ...       ...
# 2697          @SarahFortnerWx         0
# 2698                     None        18
# 2699                     None         0
# 2700                     None         3
# 2701                     None         0
#
#                                                    Text location  target  \
# 0     Nice to have a positive story about big cats f...       WI       0
# 1     my dad just told me to flood my car so I can g...       WI       1
# 2                Happy B-day Reggie, from the office!!!       WI       1
# 3     Something about how crime will magically drop ...       WI       1
# 4     Lol mine too. I’ve been avoiding floods for th...       WI       1
# ...                                                 ...      ...     ...
# 2697  Flash flood watch for Charlotte and eastward u...       TX       0
# 2698   Move to higher ground! Flash Flood Warning in...       TX       0
# 2699  Help arrives for Greenspoint flood victi http:...       TX       0
# 2700  W my fellow Capital Correspondents raising $fo...       TX       0
# 2701  Flood party @Charleston, South Carolina https:...       TX       0
#
#           user_split                                          user_text
# 0         Gabriettaa  Gabriettaa Nice to have a positive story about...
# 1        chaaasiti04  chaaasiti04 my dad just told me to flood my ca...
# 2            JDenius     JDenius Happy B-day Reggie, from the office!!!
# 3      beganovic2021  beganovic2021 Something about how crime will m...
# 4     RiskItAllRichy  RiskItAllRichy Lol mine too. I’ve been avoidin...
# ...              ...                                                ...
# 2697     CharlotteCP  CharlotteCP Flash flood watch for Charlotte an...
# 2698  NWSTallahassee  NWSTallahassee  Move to higher ground! Flash F...
# 2699     BLifeAldine  BLifeAldine Help arrives for Greenspoint flood...
# 2700    Futureteller  Futureteller W my fellow Capital Correspondent...
# 2701         ClayDix  ClayDix Flood party @Charleston, South Carolin...
#
# [2702 rows x 11 columns]
