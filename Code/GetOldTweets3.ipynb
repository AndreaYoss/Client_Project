# %% [markdown]
# # GetOldTweets3

# %% [markdown]
# ### Contents:
# - [Import Packages](#Import-Packages)
# - [Scrapping Tweets](#Scrapping-Tweets)
# - [Running with additional incidents/ locations](#Running-with-additional-incidents/-locations)

# %% [markdown]
# For this project we decided to focus on floods within the United States. To obtain flood data we scraped Tweets using the GetOldTweets3 API. These APIs allowed us to scrape tweets with certain keywords pertaining to floods, from a certain location, within a certain timeframe.

# %% [markdown]
# # Import Packages

# %%
import GetOldTweets3 as got
import pandas as pd

from warnings import catch_warnings
from warnings import filterwarnings
import warnings

warnings.simplefilter(action="ignore")

# %% [markdown]
# # Scrapping Tweets

# %% [markdown]
# Function for scrapping each state:
# Steps:
# 1. import tweets
# 2. created nested list of tweets and tweet attributes (username, text, date, retweets, favorites, mentions, hashtags, geo)
# 3. created dataframe of the list created in 2
# 4. created a target column = 0 or 1 depending on when we pulled from
# 5. created a user_split column that split usernames on ''
# 6. created 'user_text' column, which is the the 'user_split' column + 'Text' column.

# %%
def get_tweets(state, startdate, enddate, maxtweet):
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch("Flood")\
                                            .setSince(startdate)\
                                            .setUntil(enddate)\
                                            .setNear(state)\
                                            .setWithin("500mi")\
                                            .setMaxTweets(maxtweet)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)
    text_tweets = [[#tw.id,
                #tw.permalink,
                tw.username,
                #tw.to,
                tw.text,
                tw.date,
                tw.retweets,
                tw.favorites,
                tw.mentions,
                tw.hashtags,
                tw.geo] for tw in tweet]
    df_state= pd.DataFrame(text_tweets, columns = ['User', 'Text', 'Date', 'Favorites', 'Retweets', 'Mentions',
                                                    'Hashtags'  , 'Geolocation'])
    return df_state

# %%
df_1 = get_tweets('Wisconsin', "2019-07-18", "2019-07-20", 1000)

# %%
df_1.shape
# Out:
# (347, 8)

# %%
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
# 4         CajunCy  Riding the bus along I29 to @RAGBRAI_IOWA and ...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 20:57:18+00:00          0         0
# 4 2019-07-19 19:53:44+00:00          0         2            @RAGBRAI_IOWA
#
#    Hashtags Geolocation
# 0  #Respect
# 1
# 2
# 3
# 4

# %%
df_1['user_split'] = [df_1['User'][row].replace('_', ' ') for row in df_1.index]

# %%
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
# 4         CajunCy  Riding the bus along I29 to @RAGBRAI_IOWA and ...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 20:57:18+00:00          0         0
# 4 2019-07-19 19:53:44+00:00          0         2            @RAGBRAI_IOWA
#
#    Hashtags Geolocation      user_split
# 0  #Respect                  Gabriettaa
# 1                           chaaasiti04
# 2                               JDenius
# 3                        RiskItAllRichy
# 4                               CajunCy

# %%
df_1['User'].value_counts().head(25)
# Out:
# iembot_phi         24
# iembot_okx          8
# iembot_arx          8
# NWS_MountHolly      7
# TBWSirSpitta        7
# USGS_TexasFlood     5
# iembot_rlx          5
# iembot_hun          4
# manyhotzbeats       3
# kpax512             3
# TotalTrafficNYC     3
# iembot_jkl          3
# udor_visualarts     2
# LI_Weather516       2
# Bill_Flood          2
# TxMichaelDugan      2
# runhildroeder       2
# NWSMemphis          2
# FredButt6           2
# NWSCharlestonWV     2
# CrystalDcreates     2
# kristy527           2
# spotternetwork      2
# nwsjacksonky        2
# NWSTucson           2
# Name: User, dtype: int64

# %%
# 1 for it was a legitimate flood
df_1['target']=1

# %%
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
# 4         CajunCy  Riding the bus along I29 to @RAGBRAI_IOWA and ...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 20:57:18+00:00          0         0
# 4 2019-07-19 19:53:44+00:00          0         2            @RAGBRAI_IOWA
#
#    Hashtags Geolocation      user_split  target
# 0  #Respect                  Gabriettaa       1
# 1                           chaaasiti04       1
# 2                               JDenius       1
# 3                        RiskItAllRichy       1
# 4                               CajunCy       1

# %%
for i in df_1[df_1['User']== 'TBWSirSpitta'].index:
    df_1['target'][i]=0
df_1[df_1['User']=='TBWSirSpitta']
# Out:
#              User                                               Text  \
# 30   TBWSirSpitta  Don’t be that one mf that try to fuck up the v...
# 33   TBWSirSpitta  Go Pre Order “MY WAY” Now #LINKINBIO @GTDigita...
# 34   TBWSirSpitta  PRE ORDER #MYWAY The link is in my bio @applem...
# 171  TBWSirSpitta  So they ask me, “Yung boa, what you gone do th...
# 193  TBWSirSpitta  Ahhhh shit we done made it to the LAST DAY BEF...
# 203  TBWSirSpitta  Niggas couldn’t survive on this side TOMORROW ...
# 294  TBWSirSpitta  Wanna feel like this guy? Listen to #MYWAY And...
#
#                          Date  Favorites  Retweets  \
# 30  2019-07-19 03:16:55+00:00          2         2
# 33  2019-07-19 02:45:39+00:00          3         2
# 34  2019-07-19 02:40:52+00:00          2         1
# 171 2019-07-18 17:26:46+00:00          0         0
# 193 2019-07-18 13:26:47+00:00          0         0
# 203 2019-07-18 12:35:00+00:00          0         0
# 294 2019-07-18 01:01:48+00:00          1         0
#
#                         Mentions  \
# 30
# 33   @GTDigitalDIST @Goldtoes415
# 34                   @AppleMusic
# 171
# 193
# 203                  @CalvoMayne
# 294
#
#                                               Hashtags Geolocation  \
# 30   #MYWAY #LINKINBIO #TooBusyWinning #FLOOD #FOE ...
# 33   #LINKINBIO #TooBusyWinning #MYWAY #FLOOD #FOE ...
# 34           #MYWAY #FLOOD #TooBusyWinning #FLOOD #FOE
# 171  #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID #gtd...
# 193          #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID
# 203  #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID #gtd...
# 294  #MYWAY #TooBusyWinning #FLOOD #FOE #SOLID #gtd...
#
#        user_split  target
# 30   TBWSirSpitta       0
# 33   TBWSirSpitta       0
# 34   TBWSirSpitta       0
# 171  TBWSirSpitta       0
# 193  TBWSirSpitta       0
# 203  TBWSirSpitta       0
# 294  TBWSirSpitta       0

# %%
# looking at a false positive 
df_1['Text'][0]
# Out:
# "Nice to have a positive story about big cats for a change! #Respect India floods: Tired tiger takes nap in resident's bed via @BBCWorld https://www.bbc.com/news/world-asia-india-49041722 @BigCatRescue"

# %%
# changing the false positive to a target of one 
df_1['target'][0]=0

# %%
len(df_1['user_split'][0])
# Out:
# 10

# %%
df_1[df_1['user_split'].str.find('iembot')>-1]
# Out:
#            User                                               Text  \
# 10   iembot_sgf  At 6:15 PM CDT, 2 WNW Rolla [Phelps Co, MO] PU...
# 14   iembot_arx  At 3:00 AM CDT, Stockton [Winona Co, MN] EMERG...
# 15   iembot_arx  At 7:05 AM CDT, 2 NE Lewiston [Winona Co, MN] ...
# 17   iembot_arx  At 5:22 AM CDT, 1 W Coon Valley [Vernon Co, WI...
# 18   iembot_arx  At 4:13 AM CDT, 1 N Viroqua [Vernon Co, WI] LA...
# ..          ...                                                ...
# 286  iembot_phi  At 9:15 PM EDT, 1 E Burlington TWP [Burlington...
# 288  iembot_okx  At 8:30 PM EDT, Long Island City [Queens Co, N...
# 337  iembot_phi  At 8:06 PM EDT, 1 SSW Exeter TWP [Berks Co, PA...
# 344  iembot_meg  At 7:45 AM CDT, 8 ENE Tupelo [Lee Co, MS] BROA...
# 345  iembot_phi  At 7:53 PM EDT, Douglassville [Berks Co, PA] F...
#
#                          Date  Favorites  Retweets Mentions Hashtags  \
# 10  2019-07-19 13:53:26+00:00          1         0
# 14  2019-07-19 12:07:40+00:00          0         0
# 15  2019-07-19 12:07:39+00:00          0         0
# 17  2019-07-19 10:28:15+00:00          0         0
# 18  2019-07-19 09:16:25+00:00          0         0
# ..                        ...        ...       ...      ...      ...
# 286 2019-07-18 01:29:20+00:00          0         0
# 288 2019-07-18 01:17:38+00:00          0         0
# 337 2019-07-18 00:07:49+00:00          0         0
# 344 2019-07-18 00:01:43+00:00          0         0
# 345 2019-07-18 00:01:29+00:00          2         1
#
#     Geolocation  user_split  target
# 10               iembot sgf       1
# 14               iembot arx       1
# 15               iembot arx       1
# 17               iembot arx       1
# 18               iembot arx       1
# ..          ...         ...     ...
# 286              iembot phi       1
# 288              iembot okx       1
# 337              iembot phi       1
# 344              iembot meg       1
# 345              iembot phi       1
#
# [66 rows x 10 columns]

# %%
df_1['user_text'] = df_1['user_split']+' ' + df_1['Text']
df_1.head()
# Out:
#              User                                               Text  \
# 0      Gabriettaa  Nice to have a positive story about big cats f...
# 1     chaaasiti04  my dad just told me to flood my car so I can g...
# 2         JDenius             Happy B-day Reggie, from the office!!!
# 3  RiskItAllRichy  Lol mine too. I’ve been avoiding floods for th...
# 4         CajunCy  Riding the bus along I29 to @RAGBRAI_IOWA and ...
#
#                        Date  Favorites  Retweets                 Mentions  \
# 0 2019-07-19 22:40:31+00:00          0         1  @BBCWorld @BigCatRescue
# 1 2019-07-19 22:26:34+00:00          0         0
# 2 2019-07-19 22:19:05+00:00          1         2
# 3 2019-07-19 20:57:18+00:00          0         0
# 4 2019-07-19 19:53:44+00:00          0         2            @RAGBRAI_IOWA
#
#    Hashtags Geolocation      user_split  target  \
# 0  #Respect                  Gabriettaa       0
# 1                           chaaasiti04       1
# 2                               JDenius       1
# 3                        RiskItAllRichy       1
# 4                               CajunCy       1
#
#                                            user_text
# 0  Gabriettaa Nice to have a positive story about...
# 1  chaaasiti04 my dad just told me to flood my ca...
# 2     JDenius Happy B-day Reggie, from the office!!!
# 3  RiskItAllRichy Lol mine too. I’ve been avoidin...
# 4  CajunCy Riding the bus along I29 to @RAGBRAI_I...

# %% [markdown]
# Using maxtweet = 350 to make closer to balanced classes.

# %%
df_0 = get_tweets('Wisconsin', "2019-12-16", "2019-12-25", 350)

# %%
df_0['user_split'] = [df_0['User'][row].replace('_', ' ') for row in df_0.index]

# %%
df_0['user_text'] = df_0['user_split']+' ' + df_0['Text']
df_0.head()
# Out:
#              User                                               Text  \
# 0      jimistlboy  It’s an enormous injustice and it hurts my Car...
# 1  EdwardWellence  Im sorry to say some people wont find happines...
# 2        maya0818     Floods, fog create Christmas Eve travel havoc
# 3   morganabigail  Drinking a Bar Baby Blonde by @GreatFloodBeer ...
# 4    LitVolBangor  Merry Jólabókaflóð, or “Yule Book Flood"! In I...
#
#                        Date  Favorites  Retweets         Mentions  \
# 0 2019-12-24 23:29:02+00:00          1         2
# 1 2019-12-24 23:12:59+00:00          2         7
# 2 2019-12-24 23:07:44+00:00          0         0
# 3 2019-12-24 23:03:37+00:00          0         2  @GreatFloodBeer
# 4 2019-12-24 22:46:56+00:00          6        12
#
#                     Hashtags Geolocation      user_split  \
# 0                                             jimistlboy
# 1                                         EdwardWellence
# 2                                               maya0818
# 3                                          morganabigail
# 4  #delightful #ChristmasEve                LitVolBangor
#
#                                            user_text
# 0  jimistlboy It’s an enormous injustice and it h...
# 1  EdwardWellence Im sorry to say some people won...
# 2  maya0818 Floods, fog create Christmas Eve trav...
# 3  morganabigail Drinking a Bar Baby Blonde by @G...
# 4  LitVolBangor Merry Jólabókaflóð, or “Yule Book...

# %%
df_0['target']=0

# %%
df_WI = pd.concat([df_1, df_0], ignore_index = True)
df_WI.head()
# Out:
#                        Date  Favorites Geolocation  Hashtags  \
# 0 2019-07-19 22:40:31+00:00          0              #Respect
# 1 2019-07-19 22:26:34+00:00          0
# 2 2019-07-19 22:19:05+00:00          1
# 3 2019-07-19 20:57:18+00:00          0
# 4 2019-07-19 19:53:44+00:00          0
#
#                   Mentions  Retweets  \
# 0  @BBCWorld @BigCatRescue         1
# 1                                  0
# 2                                  2
# 3                                  0
# 4            @RAGBRAI_IOWA         2
#
#                                                 Text            User  target  \
# 0  Nice to have a positive story about big cats f...      Gabriettaa       0
# 1  my dad just told me to flood my car so I can g...     chaaasiti04       1
# 2             Happy B-day Reggie, from the office!!!         JDenius       1
# 3  Lol mine too. I’ve been avoiding floods for th...  RiskItAllRichy       1
# 4  Riding the bus along I29 to @RAGBRAI_IOWA and ...         CajunCy       1
#
#        user_split                                          user_text
# 0      Gabriettaa  Gabriettaa Nice to have a positive story about...
# 1     chaaasiti04  chaaasiti04 my dad just told me to flood my ca...
# 2         JDenius     JDenius Happy B-day Reggie, from the office!!!
# 3  RiskItAllRichy  RiskItAllRichy Lol mine too. I’ve been avoidin...
# 4         CajunCy  CajunCy Riding the bus along I29 to @RAGBRAI_I...

# %%
df_WI['location'] = 'WI'
df_WI.head()
# Out:
#                        Date  Favorites Geolocation  Hashtags  \
# 0 2019-07-19 22:40:31+00:00          0              #Respect
# 1 2019-07-19 22:26:34+00:00          0
# 2 2019-07-19 22:19:05+00:00          1
# 3 2019-07-19 20:57:18+00:00          0
# 4 2019-07-19 19:53:44+00:00          0
#
#                   Mentions  Retweets  \
# 0  @BBCWorld @BigCatRescue         1
# 1                                  0
# 2                                  2
# 3                                  0
# 4            @RAGBRAI_IOWA         2
#
#                                                 Text            User  target  \
# 0  Nice to have a positive story about big cats f...      Gabriettaa       0
# 1  my dad just told me to flood my car so I can g...     chaaasiti04       1
# 2             Happy B-day Reggie, from the office!!!         JDenius       1
# 3  Lol mine too. I’ve been avoiding floods for th...  RiskItAllRichy       1
# 4  Riding the bus along I29 to @RAGBRAI_IOWA and ...         CajunCy       1
#
#        user_split                                          user_text location
# 0      Gabriettaa  Gabriettaa Nice to have a positive story about...       WI
# 1     chaaasiti04  chaaasiti04 my dad just told me to flood my ca...       WI
# 2         JDenius     JDenius Happy B-day Reggie, from the office!!!       WI
# 3  RiskItAllRichy  RiskItAllRichy Lol mine too. I’ve been avoidin...       WI
# 4         CajunCy  CajunCy Riding the bus along I29 to @RAGBRAI_I...       WI

# %%
#df_WI.to_csv('../datasets/df_WI.csv')

# %%
pd.read_csv('../datasets/df_WI.csv').head()
# Out:
#    Unnamed: 0                       Date  Favorites  Geolocation  HashTags  \
# 0           0  2019-07-19 22:40:31+00:00          0          NaN  #Respect
# 1           1  2019-07-19 22:26:34+00:00          0          NaN       NaN
# 2           2  2019-07-19 22:19:05+00:00          1          NaN       NaN
# 3           3  2019-07-19 22:17:13+00:00          0          NaN       NaN
# 4           4  2019-07-19 20:57:18+00:00          0          NaN       NaN
#
#                   Mentions  Retweets  \
# 0  @BBCWorld @BigCatRescue         1
# 1                      NaN         0
# 2                      NaN         2
# 3                      NaN         0
# 4                      NaN         0
#
#                                                 Text            User  target  \
# 0  Nice to have a positive story about big cats f...      Gabriettaa       0
# 1  my dad just told me to flood my car so I can g...     chaaasiti04       1
# 2             Happy B-day Reggie, from the office!!!         JDenius       1
# 3  Something about how crime will magically drop ...   beganovic2021       1
# 4  Lol mine too. I’ve been avoiding floods for th...  RiskItAllRichy       1
#
#        user_split                                          user_text location
# 0      Gabriettaa  Gabriettaa Nice to have a positive story about...       WI
# 1     chaaasiti04  chaaasiti04 my dad just told me to flood my ca...       WI
# 2         JDenius     JDenius Happy B-day Reggie, from the office!!!       WI
# 3   beganovic2021  beganovic2021 Something about how crime will m...       WI
# 4  RiskItAllRichy  RiskItAllRichy Lol mine too. I’ve been avoidin...       WI

# %% [markdown]
# ### Running with additional incidents/ locations

# %% [markdown]
# We then scrapped Texas and Iowa for dates where a flood did occur and dates where a flood did not occur.

# %%
df_1_TX = get_tweets('Texas', "2016-05-22", "2016-06-24", 1000)

# %%
df_1_TX.shape
# Out:
# (1000, 8)

# %%
df_1_TX['user_split'] = [df_1_TX['User'][row].replace('_', ' ') for row in df_1_TX.index]
df_1_TX['user_text'] = df_1_TX['user_split']+' ' + df_1_TX['Text']
df_1_TX.head()
# Out:
#          User                                               Text  \
# 0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-06-23 23:53:45+00:00          0         0              #RLX
# 1 2016-06-23 23:50:46+00:00          0         0              #RLX
# 2 2016-06-23 23:48:01+00:00          0         0              #RLX
# 3 2016-06-23 22:27:16+00:00          0         0              #RLX
# 4 2016-06-23 22:23:57+00:00          0         0              #RNK
#
#   Geolocation  user_split                                          user_text
# 0              iembot rlx  iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...
# 1              iembot rlx  iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...
# 2              iembot rlx  iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...
# 3              iembot rlx  iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...
# 4              iembot rnk  iembot rnk At 6:00 PM, Renick [Greenbrier Co, ...

# %%
df_1_TX['target']=1

# %%
df_0_TX = get_tweets('Texas', "2016-08-22", "2016-09-24", 1000)

# %%
df_0_TX.head()
# Out:
#               User                                               Text  \
# 0   GODFATHERofICE  And it begins/has begun #ruts #snow #frozenHan...
# 1  NotMadOnline247  "Oh, Ophelia, you've been on my mind girl sinc...
# 2         tim_kite  Charity beer for flood relief! Come get some! ...
# 3   kerascreations  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4  adv_w_nancylynn  Come to the McCallie tailgate tonight and supp...
#
#                        Date  Favorites  Retweets       Mentions  \
# 0 2016-09-23 23:21:49+00:00          0         0
# 1 2016-09-23 22:58:22+00:00          0         1
# 2 2016-09-23 22:50:47+00:00          0         0  @TheAbitaBeer
# 3 2016-09-23 22:28:33+00:00          0         1
# 4 2016-09-23 21:39:13+00:00          0         1
#
#                                             Hashtags Geolocation
# 0       #ruts #snow #frozenHands #floods #doubleZams
# 1
# 2
# 3  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4

# %%
df_0_TX['user_split'] = [df_0_TX['User'][row].replace('_', ' ') for row in df_0_TX.index]
df_0_TX['user_text'] = df_0_TX['user_split']+' ' + df_0_TX['Text']
df_0_TX.head()
# Out:
#               User                                               Text  \
# 0   GODFATHERofICE  And it begins/has begun #ruts #snow #frozenHan...
# 1  NotMadOnline247  "Oh, Ophelia, you've been on my mind girl sinc...
# 2         tim_kite  Charity beer for flood relief! Come get some! ...
# 3   kerascreations  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4  adv_w_nancylynn  Come to the McCallie tailgate tonight and supp...
#
#                        Date  Favorites  Retweets       Mentions  \
# 0 2016-09-23 23:21:49+00:00          0         0
# 1 2016-09-23 22:58:22+00:00          0         1
# 2 2016-09-23 22:50:47+00:00          0         0  @TheAbitaBeer
# 3 2016-09-23 22:28:33+00:00          0         1
# 4 2016-09-23 21:39:13+00:00          0         1
#
#                                             Hashtags Geolocation  \
# 0       #ruts #snow #frozenHands #floods #doubleZams
# 1
# 2
# 3  #cedarrapids #ellisharbor #cr2016flood #prepar...
# 4
#
#         user_split                                          user_text  target
# 0   GODFATHERofICE  GODFATHERofICE And it begins/has begun #ruts #...       0
# 1  NotMadOnline247  NotMadOnline247 "Oh, Ophelia, you've been on m...       0
# 2         tim kite  tim kite Charity beer for flood relief! Come g...       0
# 3   kerascreations  kerascreations #cedarrapids #ellisharbor #cr20...       0
# 4  adv w nancylynn  adv w nancylynn Come to the McCallie tailgate ...       0

# %%
df_0_TX['target']=0

# %%
df_TX = pd.concat([df_1_TX, df_0_TX], axis = 0)

# %%
df_TX['location'] = 'TX'
df_TX.head()
# Out:
#          User                                               Text  \
# 0  iembot_rlx  At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 1  iembot_rlx  At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 2  iembot_rlx  At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 3  iembot_rlx  At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# 4  iembot_rnk  At 6:00 PM, Renick [Greenbrier Co, WV] EMERGEN...
#
#                        Date  Favorites  Retweets Mentions Hashtags  \
# 0 2016-06-23 23:53:45+00:00          0         0              #RLX
# 1 2016-06-23 23:50:46+00:00          0         0              #RLX
# 2 2016-06-23 23:48:01+00:00          0         0              #RLX
# 3 2016-06-23 22:27:16+00:00          0         0              #RLX
# 4 2016-06-23 22:23:57+00:00          0         0              #RNK
#
#   Geolocation  user_split                                          user_text  \
# 0              iembot rlx  iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...
# 1              iembot rlx  iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...
# 2              iembot rlx  iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...
# 3              iembot rlx  iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...
# 4              iembot rnk  iembot rnk At 6:00 PM, Renick [Greenbrier Co, ...
#
#    target location
# 0       1       TX
# 1       1       TX
# 2       1       TX
# 3       1       TX
# 4       1       TX

# %%
#df_TX.to_csv('../datasets/df_TX.csv')

# %%
pd.read_csv('../datasets/df_TX.csv')
# Out:
#       Unnamed: 0            User  \
# 0              0      LisaAbeyta
# 1              1      iembot_rlx
# 2              2      iembot_rlx
# 3              3      iembot_rlx
# 4              4      iembot_rlx
# ...          ...             ...
# 1995         995     CharlotteCP
# 1996         996  NWSTallahassee
# 1997         997     BLifeAldine
# 1998         998    Futureteller
# 1999         999         ClayDix
#
#                                                    Text  \
# 0     Flash flood warning until 7 PM #nmwx #nm @Albu...
# 1     At 7:51 PM, 2 NNE Rush [Boyd Co, KY] EMERGENCY...
# 2     At 7:48 PM, 4 SSE Rush [Boyd Co, KY] EMERGENCY...
# 3     At 7:44 PM, Rush [Boyd Co, KY] EMERGENCY MNGR ...
# 4     At 6:03 PM, 3 SW Amma [Roane Co, WV] DEPT OF H...
# ...                                                 ...
# 1995  Flash flood watch for Charlotte and eastward u...
# 1996   Move to higher ground! Flash Flood Warning in...
# 1997  Help arrives for Greenspoint flood victi http:...
# 1998  W my fellow Capital Correspondents raising $fo...
# 1999  Flood party @Charleston, South Carolina https:...
#
#                            Date  Favorites  Retweets         Mentions  \
# 0     2016-06-23 23:59:36+00:00          0         0              NaN
# 1     2016-06-23 23:53:45+00:00          0         0              NaN
# 2     2016-06-23 23:50:46+00:00          0         0              NaN
# 3     2016-06-23 23:48:01+00:00          0         0              NaN
# 4     2016-06-23 22:27:16+00:00          0         0              NaN
# ...                         ...        ...       ...              ...
# 1995  2016-09-02 09:56:07+00:00          0         0  @SarahFortnerWx
# 1996  2016-09-02 05:19:09+00:00         56        18              NaN
# 1997  2016-09-02 04:47:49+00:00          0         0              NaN
# 1998  2016-09-02 02:49:25+00:00          0         3              NaN
# 1999  2016-09-02 02:46:37+00:00          0         0              NaN
#
#        HashTags  Geolocation      user_split  \
# 0     #nmwx #nm          NaN      LisaAbeyta
# 1          #RLX          NaN      iembot rlx
# 2          #RLX          NaN      iembot rlx
# 3          #RLX          NaN      iembot rlx
# 4          #RLX          NaN      iembot rlx
# ...         ...          ...             ...
# 1995        NaN          NaN     CharlotteCP
# 1996        NaN          NaN  NWSTallahassee
# 1997        NaN          NaN     BLifeAldine
# 1998        NaN          NaN    Futureteller
# 1999        NaN          NaN         ClayDix
#
#                                               user_text  target location
# 0     LisaAbeyta Flash flood warning until 7 PM #nmw...       1       TX
# 1     iembot rlx At 7:51 PM, 2 NNE Rush [Boyd Co, KY...       1       TX
# 2     iembot rlx At 7:48 PM, 4 SSE Rush [Boyd Co, KY...       1       TX
# 3     iembot rlx At 7:44 PM, Rush [Boyd Co, KY] EMER...       1       TX
# 4     iembot rlx At 6:03 PM, 3 SW Amma [Roane Co, WV...       1       TX
# ...                                                 ...     ...      ...
# 1995  CharlotteCP Flash flood watch for Charlotte an...       0       TX
# 1996  NWSTallahassee  Move to higher ground! Flash F...       0       TX
# 1997  BLifeAldine Help arrives for Greenspoint flood...       0       TX
# 1998  Futureteller W my fellow Capital Correspondent...       0       TX
# 1999  ClayDix Flood party @Charleston, South Carolin...       0       TX
#
# [2000 rows x 13 columns]

# %% [markdown]
# y=1 data, Iowa

# %%
df_1_IA = get_tweets('Iowa', "2016-09-21", "2016-10-03", 1000)

# %%
df_1_IA['user_split'] = [df_1_IA['User'][row].replace('_', ' ') for row in df_1_IA.index]
df_1_IA['user_text'] = df_1_IA['user_split']+' ' + df_1_IA['Text']
df_1_IA.shape
# Out:
# (665, 10)

# %%
df_1_IA['target']=1
df_1_IA.head()
# Out:
#             User                                               Text  \
# 0     TooCute504  Took the time out to volunteer in BR today. Pe...
# 1      juliakate  The great Paducah Flood Wall Murals... this At...
# 2  Slapfish_2009  The Barman's Fund and USBG Tailgate Benefit fo...
# 3     AhleahZoe1  Flood waters. @Downtown Burlington IA https://...
# 4      katyxbeth  Last night sure was rainy as seen right before...
#
#                        Date  Favorites  Retweets Mentions           Hashtags  \
# 0 2016-10-02 23:06:20+00:00          0         0
# 1 2016-10-02 22:43:33+00:00          0         0
# 2 2016-10-02 20:32:22+00:00          0         0           #DrinkWithPurpose
# 3 2016-10-02 18:01:34+00:00          0         0
# 4 2016-10-02 17:54:06+00:00          0         0
#
#   Geolocation     user_split  \
# 0                 TooCute504
# 1                  juliakate
# 2              Slapfish 2009
# 3                 AhleahZoe1
# 4                  katyxbeth
#
#                                            user_text  target
# 0  TooCute504 Took the time out to volunteer in B...       1
# 1  juliakate The great Paducah Flood Wall Murals....       1
# 2  Slapfish 2009 The Barman's Fund and USBG Tailg...       1
# 3  AhleahZoe1 Flood waters. @Downtown Burlington ...       1
# 4  katyxbeth Last night sure was rainy as seen ri...       1

# %% [markdown]
# Doing a little cleaning here, reclassifying some targets.

# %%
df_1_IA['target'][[0,1,2,4,5,22,23, 24]]=0

# %% [markdown]
# y=0, Iowa

# %%
# y= 0, Iowa tweets
# change function to max tweet of 660 from 1000 to balance it out
df_0_IA = get_tweets('Iowa', "2017-09-01", "2017-10-21", 660)

# %%
df_0_IA['user_split'] = [df_0_IA['User'][row].replace('_', ' ') for row in df_0_IA.index]
df_0_IA['user_text'] = df_0_IA['user_split']+' ' + df_0_IA['Text']
df_0_IA.head()
# Out:
#               User                                               Text  \
# 0   timinhollywood  Excuse me while I flood my timeline with Howar...
# 1       iembot_hgx  At 6:00 AM, 3 W League City [Galveston Co, TX]...
# 2       NWSHouston  Flash Flood Warning including League City TX, ...
# 3  USGS_TexasFlood  #USGS08030500 - Sabine Rv nr Ruliff, TX is abo...
# 4    StreetDiamond  It's @monroekush - Prepping for "Operation Flo...
#
#                        Date  Favorites  Retweets     Mentions  \
# 0 2017-10-20 19:11:14+00:00          0         0
# 1 2017-10-20 14:52:39+00:00          0         0
# 2 2017-10-20 09:52:18+00:00          7         3
# 3 2017-10-20 07:01:38+00:00          0         1
# 4 2017-10-20 02:46:57+00:00         11         0  @MonroeKush
#
#                     Hashtags Geolocation       user_split  \
# 0                                          timinhollywood
# 1                       #HGX                   iembot hgx
# 2                                              NWSHouston
# 3              #USGS08030500              USGS TexasFlood
# 4  #Loading #GetYourLIGHTERS                StreetDiamond
#
#                                            user_text
# 0  timinhollywood Excuse me while I flood my time...
# 1  iembot hgx At 6:00 AM, 3 W League City [Galves...
# 2  NWSHouston Flash Flood Warning including Leagu...
# 3  USGS TexasFlood #USGS08030500 - Sabine Rv nr R...
# 4  StreetDiamond It's @monroekush - Prepping for ...

# %%
df_0_IA['target']=0

# %%
df_IA = pd.concat([df_1_IA, df_0_IA], axis = 0)

# %%
df_IA['location'] = 'IA'

# %%
# df_IA.to_csv('../datasets/df_IA.csv')

# %%
pd.read_csv('../datasets/df_IA.csv').head()
# Out:
#    Unnamed: 0           User  \
# 0           0     TooCute504
# 1           1      juliakate
# 2           2  Slapfish_2009
# 3           3     AhleahZoe1
# 4           4      katyxbeth
#
#                                                 Text  \
# 0  Took the time out to volunteer in BR today. Pe...
# 1  The great Paducah Flood Wall Murals... this At...
# 2  The Barman's Fund and USBG Tailgate Benefit fo...
# 3  Flood waters. @Downtown Burlington IA https://...
# 4  Last night sure was rainy as seen right before...
#
#                         Date  Favorites  Retweets Mentions           HashTags  \
# 0  2016-10-02 23:06:20+00:00          0         0      NaN                NaN
# 1  2016-10-02 22:43:33+00:00          0         0      NaN                NaN
# 2  2016-10-02 20:32:22+00:00          0         0      NaN  #DrinkWithPurpose
# 3  2016-10-02 18:01:34+00:00          0         0      NaN                NaN
# 4  2016-10-02 17:54:06+00:00          0         0      NaN                NaN
#
#    Geolocation     user_split  \
# 0          NaN     TooCute504
# 1          NaN      juliakate
# 2          NaN  Slapfish 2009
# 3          NaN     AhleahZoe1
# 4          NaN      katyxbeth
#
#                                            user_text  target location
# 0  TooCute504 Took the time out to volunteer in B...       0       IA
# 1  juliakate The great Paducah Flood Wall Murals....       0       IA
# 2  Slapfish 2009 The Barman's Fund and USBG Tailg...       0       IA
# 3  AhleahZoe1 Flood waters. @Downtown Burlington ...       1       IA
# 4  katyxbeth Last night sure was rainy as seen ri...       0       IA

# %% [markdown]
# We used the combined data from this model to scrape the tweets.
